# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
mnist = keras.datasets.mnist

# %%
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

# %%
img = X_train[0]

# %%
plt.imshow(img)

# %%
eigenvalues, eigenvectors = np.linalg.eigh(img)

# %%
eigenvalues
# Out:
# array([-9.96868333e+02, -6.97153309e+02, -3.68757284e+02, -1.19652738e+02,
#        -7.25091892e+01, -3.54965377e+01,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  5.96876911e-02,  1.80416242e+00,  2.38822678e+01,
#         6.46149655e+01,  8.35094705e+01,  1.16981164e+02,  1.22029711e+02,
#         1.41492751e+02,  1.87829390e+02,  2.32212274e+02,  2.59575497e+02,
#         3.44336503e+02,  6.46241573e+02,  1.00747688e+03,  1.25639110e+03])

# %%
plt.imshow(eigenvectors * eigenvalues)
