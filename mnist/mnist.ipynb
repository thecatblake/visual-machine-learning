# %%
import tensorflow as tf
import numpy as np
import keras
import matplotlib.pyplot as plt
from PIL import Image

# %%
EPOCHS = 50
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2

# %%
mnist = keras.datasets.mnist

(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784
X_train = X_train.reshape(-1, RESHAPED)
X_test = X_test.reshape(-1, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

X_train /= 255
X_test /= 255

Y_train = keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = keras.utils.to_categorical(Y_test, NB_CLASSES)

# %%
model = keras.models.Sequential([
    keras.layers.Dense(NB_CLASSES,
                       input_shape=(RESHAPED,),
                       name="dense_layer",
                       activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape              ┃    Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ dense_layer (Dense)             │ (None, 10)                │      7,850 │
# └─────────────────────────────────┴───────────────────────────┴────────────┘
#  Total params: 7,850 (30.66 KB)
#  Trainable params: 7,850 (30.66 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="SGD", loss="categorical_crossentropy", metrics=["accuracy"])
history = model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4727 - loss: 1.7938 - val_accuracy: 0.8255 - val_loss: 0.8951
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8136 - loss: 0.8553 - val_accuracy: 0.8592 - val_loss: 0.6562
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8440 - loss: 0.6709 - val_accuracy: 0.8704 - val_loss: 0.5609
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8567 - loss: 0.5864 - val_accuracy: 0.8770 - val_loss: 0.5083
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8663 - loss: 0.5339 - val_accuracy: 0.8818 - val_loss: 0.4745
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8709 - loss: 0.5042 - val_accuracy: 0.8874 - val_loss: 0.4504
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8777 - loss: 0.4739 - val_accuracy: 0.8898 - val_loss: 0.4324
# Epoch 8/50
# ...

# %%
ws = model.layers[0].weights[0].numpy().reshape((28, 28, 10))

# %%
model = keras.models.Sequential([
    keras.layers.Dropout(rate=0.6),    
    keras.layers.Dense(NB_CLASSES,
                       input_shape=(RESHAPED,),
                       name="dense_layer",
                       activation="softmax")
])
model.compile(optimizer="SGD", loss="categorical_crossentropy", metrics=["accuracy"])
history = model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3664 - loss: 1.8673 - val_accuracy: 0.8281 - val_loss: 0.9002
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7171 - loss: 1.0042 - val_accuracy: 0.8551 - val_loss: 0.6693
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7682 - loss: 0.8206 - val_accuracy: 0.8693 - val_loss: 0.5771
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7930 - loss: 0.7324 - val_accuracy: 0.8744 - val_loss: 0.5266
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7996 - loss: 0.6918 - val_accuracy: 0.8797 - val_loss: 0.4945
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8071 - loss: 0.6661 - val_accuracy: 0.8837 - val_loss: 0.4718
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8138 - loss: 0.6362 - val_accuracy: 0.8859 - val_loss: 0.4542
# Epoch 8/50
# ...

# %%
ws_dropout = model.layers[1].weights[0].numpy().reshape((28, 28, 10))

# %%
figure, axis = plt.subplots(nrows=10, ncols=2, figsize=(100, 100))
figure.tight_layout(pad=0)

for i in range(10):
    axis[i, 0].imshow(ws[:, :, i])
    axis[i, 1].imshow(ws_dropout[:, :, i])
plt.savefig("./mnist_dropout.png")
